# %% [markdown]
# # Lyric Generator!
#
# Further to my studies of NLP, I decided to see whether I could harness AI to write new lyrics based on my previous listening habits.

# %% [markdown]
# First I pulled my data from the Spotify API. Initially I was going to use only my top 100 songs from 2019 (according to Spotify) but I decided to use the same from 2018 as well in order to increased the size of the corpus used to train my model. I have left the code here for reference, but you can find the data that I actually used here.
#
# In order to run my notebook, please download the dataset and put it in the data folder.

# %%
#Import libraries
import spotipy.util as util
import spotipy
import os.path as path
import requests
from bs4 import BeautifulSoup
import re
from spotipy.oauth2 import SpotifyClientCredentials
from better_profanity import profanity
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GRU, Dense, Input, Embedding, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
import random

# %%
# username = 'ninahew'
# spotify_client_id ='a758a8092e3b45949388c4123f79948f'
# spotify_client_secret = 'df4c710d84b64ab7810f0b9b055a07f2'
# redirect_uri = 'http://localhost:7777/callback'
# scope = 'user-read-recently-played'
# genius_key = 'sQkNdeBg0aT9rz89yElRfHbxE_UIW3kFs9IkXPIH6Ab4cH8DvfikT09FU56MVjZP'
# spotify_playlist_id = 'spotify:playlist:37i9dQZF1EtmAVggpyt82c'
# spotify_user_id = 'spotify:user:ninahew'


#spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, 
#                                                                             client_secret=client_secret))

# %% [markdown]
# In order to pull the lyrics to my playlists, there are a few steps that need to be done.
# From Spotify:
# 1) Pull the playlist info
#
# 2) Pull the track names for each song
#
# 3) Pull the artists names for each song
#
#
# THEN
#
# 4) Using the Genius API, the song name and artist, pull the song information
#
# 5) Check whether the tracks are included on the Genius API
#
# 6) If they're included, pull the url for the song's page
#
# 7) Scrape the lyrics from the page
#
# 8) Finally, return the results

# %%
# class GetLyrics():
    
#     def __init__(self, spotify_client_id, spotify_client_secret, user_id, playlist_id, genius_key):
#         self.spotify_client_id = spotify_client_id
#         self.spotify_client_secret = spotify_client_secret
#         self.user_id = user_id
#         self.playlist_id = playlist_id
#         self.genius_key = genius_key
        
#     def get_playlist_info(self):
#         token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
#         sp = spotipy.Spotify(token)
#         playlist = sp.user_playlist_tracks(self.user_id, self.playlist_id)
#         self.playlist = playlist
#         return self.playlist
    
#     def get_track_names(self):
#         track_names = []
#         for song in range(len(self.playlist['items'])):
#             track_names.append(self.playlist['items'][song]['track']['name'])
#         self.track_names = track_names
#         return self.track_names
    
#     def get_track_artists(self):
#         track_artists = []
#         for song in range(len(self.playlist['items'])):
#             track_artists.append(self.playlist['items'][song]['track']['artists'][0]['name'])
#         self.track_artists = track_artists
#         return self.track_artists
        
#     def request_song_info(self, track_name, track_artist):
#         self.track_name = track_name
#         self.track_artist = track_artist
#         base_url = 'https://api.genius.com'
#         headers = {'Authorization': 'Bearer ' + self.genius_key}
#         search_url = base_url + '/search'
#         data = {'q': track_name + ' ' + track_artist}
#         response = requests.get(search_url, data=data, headers=headers)
#         self.response = response
#         return self.response

#     def check_hits(self):
#         json = self.response.json()
#         remote_song_info = None
#         for hit in json['response']['hits']:
#             if self.track_artist.lower() in hit['result']['primary_artist']['name'].lower():
#                 remote_song_info = hit
#                 break
#         self.remote_song_info = remote_song_info
#         return self.remote_song_info
    
#     def get_url(self):
#         song_url = self.remote_song_info['result']['url']
#         self.song_url = song_url
#         return self.song_url
    
#     def scrape_lyrics(self):
#         page = requests.get(self.song_url)
#         html = BeautifulSoup(page.text, 'html.parser')
#         lyrics1 = html.find("div", class_="lyrics")
#         lyrics2 = html.find("div", class_="Lyrics__Container-sc-1ynbvzw-2 jgQsqn")
#         if lyrics1:
#             lyrics = lyrics1.get_text()
#         elif lyrics2:
#             lyrics = lyrics2.get_text()
#         elif lyrics1 == lyrics2 == None:
#             lyrics = None
#         return lyrics

#     def get_lyrics(self):
#         playlist = GetLyrics.get_playlist_info(self)
#         track_names = GetLyrics.get_track_names(self)
#         track_artists = GetLyrics.get_track_artists(self)
#         song_lyrics = []
#         for i in range(len(self.track_names)):
#             print("\n")
#             print(f"Working on track {i}.")
#             response = GetLyrics.request_song_info(self, self.track_names[i], self.track_artists[i])
#             remote_song_info = GetLyrics.check_hits(self)
#             if remote_song_info == None:
#                 lyrics = None
#                 print(f"Track {i} is not in the Genius database.")
#             else:
#                 url = GetLyrics.get_url(self)
#                 lyrics = GetLyrics.scrape_lyrics(self)
#                 if lyrics == None:
#                     print(f"Track {i} is not in the Genius database.")
#                 else:
#                     print(f"Retrieved track {i} lyrics!")
#             song_lyrics.append(lyrics)
#         return song_lyrics

# %% [markdown]
# Next, I put this into action, pulling both playlists separately.

# %%
# songs2019 = GetLyrics(spotify_client_id, spotify_client_secret, spotify_user_id, spotify_playlist_id, genius_key)
# song_lyrics2019 = songs2019.get_lyrics()
# Out:
# <ipython-input-2-7c333718245f>:11: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
# Working on track 0.
# Retrieved track 0 lyrics!
#
#
# Working on track 1.
# Track 1 is not in the Genius database.
#
#
# Working on track 2.
# Track 2 is not in the Genius database.
#
#
# Working on track 3.
# Retrieved track 3 lyrics!
#
#
# Working on track 4.
# Retrieved track 4 lyrics!
#
#
# Working on track 5.
# Retrieved track 5 lyrics!
#
#
# Working on track 6.
# Track 6 is not in the Genius database.
#
#
# Working on track 7.
# Retrieved track 7 lyrics!
#
#
# Working on track 8.
# Track 8 is not in the Genius database.
#
#
# Working on track 9.
# Retrieved track 9 lyrics!
#
#
# Working on track 10.
# Track 10 is not in the Genius database.
#
#
# Working on track 11.
# Retrieved track 11 lyrics!
#
#
# Working on track 12.
# Track 12 is not in the Genius database.
#
#
# Working on track 13.
# Retrieved track 13 lyrics!
#
#
# Working on track 14.
# Track 14 is not in the Genius database.
#
#
# Working on track 15.
# Retrieved track 15 lyrics!
#
#
# Working on track 16.
# Retrieved track 16 lyrics!
#
#
# Working on track 17.
# Track 17 is not in the Genius database.
#
#
# Working on track 18.
# Track 18 is not in the Genius database.
#
#
# Working on track 19.
# Track 19 is not in the Genius database.
#
#
# Working on track 20.
# Retrieved track 20 lyrics!
#
#
# Working on track 21.
# Track 21 is not in the Genius database.
#
#
# Working on track 22.
# Retrieved track 22 lyrics!
#
#
# Working on track 23.
# Retrieved track 23 lyrics!
#
#
# Working on track 24.
# Retrieved track 24 lyrics!
#
#
# Working on track 25.
# Retrieved track 25 lyrics!
#
#
# Working on track 26.
# Retrieved track 26 lyrics!
#
#
# Working on track 27.
# Retrieved track 27 lyrics!
#
#
# Working on track 28.
# Retrieved track 28 lyrics!
#
#
# Working on track 29.
# Track 29 is not in the Genius database.
#
#
# Working on track 30.
# Track 30 is not in the Genius database.
#
#
# Working on track 31.
# Retrieved track 31 lyrics!
#
#
# Working on track 32.
# Track 32 is not in the Genius database.
#
#
# Working on track 33.
# Track 33 is not in the Genius database.
#
#
# Working on track 34.
# Retrieved track 34 lyrics!
#
#
# Working on track 35.
# Retrieved track 35 lyrics!
#
#
# Working on track 36.
# Retrieved track 36 lyrics!
#
#
# Working on track 37.
# Track 37 is not in the Genius database.
#
#
# Working on track 38.
# Track 38 is not in the Genius database.
#
#
# Working on track 39.
# Track 39 is not in the Genius database.
#
#
# Working on track 40.
# Track 40 is not in the Genius database.
#
#
# Working on track 41.
# Track 41 is not in the Genius database.
#
#
# Working on track 42.
# Track 42 is not in the Genius database.
#
#
# Working on track 43.
# Retrieved track 43 lyrics!
#
#
# Working on track 44.
# Retrieved track 44 lyrics!
#
#
# Working on track 45.
# Retrieved track 45 lyrics!
#
#
# Working on track 46.
# Retrieved track 46 lyrics!
#
#
# Working on track 47.
# Retrieved track 47 lyrics!
#
#
# Working on track 48.
# Retrieved track 48 lyrics!
#
#
# Working on track 49.
# Retrieved track 49 lyrics!
#
#
# Working on track 50.
# Retrieved track 50 lyrics!
#
#
# Working on track 51.
# Track 51 is not in the Genius database.
#
#
# Working on track 52.
# Track 52 is not in the Genius database.
#
#
# Working on track 53.
# Track 53 is not in the Genius database.
#
#
# Working on track 54.
# Retrieved track 54 lyrics!
#
#
# Working on track 55.
# Track 55 is not in the Genius database.
#
#
# Working on track 56.
# Retrieved track 56 lyrics!
#
#
# Working on track 57.
# Track 57 is not in the Genius database.
#
#
# Working on track 58.
# Retrieved track 58 lyrics!
#
#
# Working on track 59.
# Track 59 is not in the Genius database.
#
#
# Working on track 60.
# Track 60 is not in the Genius database.
#
#
# Working on track 61.
# Track 61 is not in the Genius database.
#
#
# Working on track 62.
# Retrieved track 62 lyrics!
#
#
# Working on track 63.
# Retrieved track 63 lyrics!
#
#
# Working on track 64.
# Track 64 is not in the Genius database.
#
#
# Working on track 65.
# Track 65 is not in the Genius database.
#
#
# Working on track 66.
# Retrieved track 66 lyrics!
#
#
# Working on track 67.
# Retrieved track 67 lyrics!
#
#
# Working on track 68.
# Track 68 is not in the Genius database.
#
#
# Working on track 69.
# Retrieved track 69 lyrics!
#
#
# Working on track 70.
# Track 70 is not in the Genius database.
#
#
# Working on track 71.
# Retrieved track 71 lyrics!
#
#
# Working on track 72.
# Retrieved track 72 lyrics!
#
#
# Working on track 73.
# Retrieved track 73 lyrics!
#
#
# Working on track 74.
# Retrieved track 74 lyrics!
#
#
# Working on track 75.
# Track 75 is not in the Genius database.
#
#
# Working on track 76.
# Retrieved track 76 lyrics!
#
#
# Working on track 77.
# Track 77 is not in the Genius database.
#
#
# Working on track 78.
# Retrieved track 78 lyrics!
#
#
# Working on track 79.
# Retrieved track 79 lyrics!
#
#
# Working on track 80.
# Retrieved track 80 lyrics!
#
#
# Working on track 81.
# Retrieved track 81 lyrics!
#
#
# Working on track 82.
# Track 82 is not in the Genius database.
#
#
# Working on track 83.
# Retrieved track 83 lyrics!
#
#
# Working on track 84.
# Retrieved track 84 lyrics!
#
#
# Working on track 85.
# Retrieved track 85 lyrics!
#
#
# Working on track 86.
# Retrieved track 86 lyrics!
#
#
# Working on track 87.
# Retrieved track 87 lyrics!
#
#
# Working on track 88.
# Retrieved track 88 lyrics!
#
#
# Working on track 89.
# Track 89 is not in the Genius database.
#
#
# Working on track 90.
# Retrieved track 90 lyrics!
#
#
# Working on track 91.
# Track 91 is not in the Genius database.
#
#
# Working on track 92.
# Retrieved track 92 lyrics!
#
#
# Working on track 93.
# Retrieved track 93 lyrics!
#
#
# Working on track 94.
# Retrieved track 94 lyrics!
#
#
# Working on track 95.
# Track 95 is not in the Genius database.
#
#
# Working on track 96.
# Retrieved track 96 lyrics!
#
#
# Working on track 97.
# Retrieved track 97 lyrics!
#
#
# Working on track 98.
# Retrieved track 98 lyrics!
#
#
# Working on track 99.
# Retrieved track 99 lyrics!

# %%
# spotify_playlist_id = 'spotify:playlist:37i9dQZF1Ejy4HBpGZqQ6f'
# songs2018 = GetLyrics(spotify_client_id, spotify_client_secret, spotify_user_id, spotify_playlist_id, genius_key)
# song_lyrics2018 = songs2018.get_lyrics()
# Out:
# <ipython-input-2-7c333718245f>:11: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
# Working on track 0.
# Retrieved track 0 lyrics!
#
#
# Working on track 1.
# Retrieved track 1 lyrics!
#
#
# Working on track 2.
# Track 2 is not in the Genius database.
#
#
# Working on track 3.
# Retrieved track 3 lyrics!
#
#
# Working on track 4.
# Track 4 is not in the Genius database.
#
#
# Working on track 5.
# Track 5 is not in the Genius database.
#
#
# Working on track 6.
# Retrieved track 6 lyrics!
#
#
# Working on track 7.
# Retrieved track 7 lyrics!
#
#
# Working on track 8.
# Retrieved track 8 lyrics!
#
#
# Working on track 9.
# Retrieved track 9 lyrics!
#
#
# Working on track 10.
# Retrieved track 10 lyrics!
#
#
# Working on track 11.
# Retrieved track 11 lyrics!
#
#
# Working on track 12.
# Retrieved track 12 lyrics!
#
#
# Working on track 13.
# Retrieved track 13 lyrics!
#
#
# Working on track 14.
# Retrieved track 14 lyrics!
#
#
# Working on track 15.
# Track 15 is not in the Genius database.
#
#
# Working on track 16.
# Track 16 is not in the Genius database.
#
#
# Working on track 17.
# Retrieved track 17 lyrics!
#
#
# Working on track 18.
# Retrieved track 18 lyrics!
#
#
# Working on track 19.
# Retrieved track 19 lyrics!
#
#
# Working on track 20.
# Retrieved track 20 lyrics!
#
#
# Working on track 21.
# Track 21 is not in the Genius database.
#
#
# Working on track 22.
# Retrieved track 22 lyrics!
#
#
# Working on track 23.
# Retrieved track 23 lyrics!
#
#
# Working on track 24.
# Retrieved track 24 lyrics!
#
#
# Working on track 25.
# Retrieved track 25 lyrics!
#
#
# Working on track 26.
# Track 26 is not in the Genius database.
#
#
# Working on track 27.
# Retrieved track 27 lyrics!
#
#
# Working on track 28.
# Retrieved track 28 lyrics!
#
#
# Working on track 29.
# Retrieved track 29 lyrics!
#
#
# Working on track 30.
# Retrieved track 30 lyrics!
#
#
# Working on track 31.
# Retrieved track 31 lyrics!
#
#
# Working on track 32.
# Retrieved track 32 lyrics!
#
#
# Working on track 33.
# Retrieved track 33 lyrics!
#
#
# Working on track 34.
# Retrieved track 34 lyrics!
#
#
# Working on track 35.
# Retrieved track 35 lyrics!
#
#
# Working on track 36.
# Retrieved track 36 lyrics!
#
#
# Working on track 37.
# Retrieved track 37 lyrics!
#
#
# Working on track 38.
# Retrieved track 38 lyrics!
#
#
# Working on track 39.
# Retrieved track 39 lyrics!
#
#
# Working on track 40.
# Retrieved track 40 lyrics!
#
#
# Working on track 41.
# Retrieved track 41 lyrics!
#
#
# Working on track 42.
# Retrieved track 42 lyrics!
#
#
# Working on track 43.
# Track 43 is not in the Genius database.
#
#
# Working on track 44.
# Track 44 is not in the Genius database.
#
#
# Working on track 45.
# Track 45 is not in the Genius database.
#
#
# Working on track 46.
# Retrieved track 46 lyrics!
#
#
# Working on track 47.
# Track 47 is not in the Genius database.
#
#
# Working on track 48.
# Retrieved track 48 lyrics!
#
#
# Working on track 49.
# Retrieved track 49 lyrics!
#
#
# Working on track 50.
# Track 50 is not in the Genius database.
#
#
# Working on track 51.
# Retrieved track 51 lyrics!
#
#
# Working on track 52.
# Retrieved track 52 lyrics!
#
#
# Working on track 53.
# Retrieved track 53 lyrics!
#
#
# Working on track 54.
# Track 54 is not in the Genius database.
#
#
# Working on track 55.
# Retrieved track 55 lyrics!
#
#
# Working on track 56.
# Retrieved track 56 lyrics!
#
#
# Working on track 57.
# Retrieved track 57 lyrics!
#
#
# Working on track 58.
# Retrieved track 58 lyrics!
#
#
# Working on track 59.
# Retrieved track 59 lyrics!
#
#
# Working on track 60.
# Retrieved track 60 lyrics!
#
#
# Working on track 61.
# Retrieved track 61 lyrics!
#
#
# Working on track 62.
# Track 62 is not in the Genius database.
#
#
# Working on track 63.
# Retrieved track 63 lyrics!
#
#
# Working on track 64.
# Track 64 is not in the Genius database.
#
#
# Working on track 65.
# Retrieved track 65 lyrics!
#
#
# Working on track 66.
# Retrieved track 66 lyrics!
#
#
# Working on track 67.
# Retrieved track 67 lyrics!
#
#
# Working on track 68.
# Track 68 is not in the Genius database.
#
#
# Working on track 69.
# Retrieved track 69 lyrics!
#
#
# Working on track 70.
# Retrieved track 70 lyrics!
#
#
# Working on track 71.
# Retrieved track 71 lyrics!
#
#
# Working on track 72.
# Track 72 is not in the Genius database.
#
#
# Working on track 73.
# Track 73 is not in the Genius database.
#
#
# Working on track 74.
# Retrieved track 74 lyrics!
#
#
# Working on track 75.
# Retrieved track 75 lyrics!
#
#
# Working on track 76.
# Track 76 is not in the Genius database.
#
#
# Working on track 77.
# Retrieved track 77 lyrics!
#
#
# Working on track 78.
# Retrieved track 78 lyrics!
#
#
# Working on track 79.
# Retrieved track 79 lyrics!
#
#
# Working on track 80.
# Track 80 is not in the Genius database.
#
#
# Working on track 81.
# Retrieved track 81 lyrics!
#
#
# Working on track 82.
# Retrieved track 82 lyrics!
#
#
# Working on track 83.
# Retrieved track 83 lyrics!
#
#
# Working on track 84.
# Retrieved track 84 lyrics!
#
#
# Working on track 85.
# Track 85 is not in the Genius database.
#
#
# Working on track 86.
# Retrieved track 86 lyrics!
#
#
# Working on track 87.
# Retrieved track 87 lyrics!
#
#
# Working on track 88.
# Track 88 is not in the Genius database.
#
#
# Working on track 89.
# Retrieved track 89 lyrics!
#
#
# Working on track 90.
# Track 90 is not in the Genius database.
#
#
# Working on track 91.
# Retrieved track 91 lyrics!
#
#
# Working on track 92.
# Retrieved track 92 lyrics!
#
#
# Working on track 93.
# Retrieved track 93 lyrics!
#
#
# Working on track 94.
# Retrieved track 94 lyrics!
#
#
# Working on track 95.
# Retrieved track 95 lyrics!
#
#
# Working on track 96.
# Retrieved track 96 lyrics!
#
#
# Working on track 97.
# Retrieved track 97 lyrics!
#
#
# Working on track 98.
# Retrieved track 98 lyrics!
#
#
# Working on track 99.
# Track 99 is not in the Genius database.

# %% [markdown]
# I wanted to double check it had worked, so I checked the first two tracks. Turns out those were Juice by Lizzo and Finesse by Bruno Mars. Unexpected, but who am I to argue with the Spotify algorithm.

# %%
# song_lyrics2019[0]
# Out:
# "[Verse 1]Mirror, mirror on the wallDon't say it ’cause I know I'm cute (Ooh, baby)Louis down to my drawersLV all on my shoes (Ooh, baby)I be drippin' so much sauceGot a bih lookin’ like RAGÚ (Ooh, baby)Lit up like a crystal ballThat's cool, baby, so is youThat's how I roll[Pre-Chorus]If I'm shinin', everybody gonna shine (Yeah, I'm goals)I was born like this, don't even gotta try (Now you know)I'm like chardonnay, get better over time (So you know)Heard you say I’m not the baddest, bitch, you lie (Haha)[Chorus]It ain’t my fault that I'm out here gettin’ looseGotta blame it on the GooseGotta blame it on my juice, babyIt ain't my fault that I'm out here makin' newsI’m the pudding in the proofGotta blame it on my juiceYa-ya-ee, ya-ya-ee, ya-ya-ee, ya-ya-eeBlame it on my juice, blame it, blame it on my juiceYa-ya-ee, ya-ya-ee, ya-ya-ee, ya-ya-eeBlame it on my juice, blame it, blame it on my juice (Ooh, baby)"

# %%
# song_lyrics2018[0]
# Out:
# "\n\n[Verse 1]\nOoh, don't we look good together?\nThere's a reason why they watch all night long\nYeah, know we'll turn heads forever\nSo tonight I'm gonna show you off\n\n[Pre-Chorus]\nWhen I'm walkin' with you\nI watch the whole room change\nBaby, that's what you do\nNo my baby don't play\nBlame it on my confidence\nOh, blame it on your measurements\nShut that shit down on sight\nThat's right\n\n[Chorus]\nWe out here drippin' in finesse\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it\nWe out here drippin' in finesse\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it\n\n[Verse 2]\nNow slow it down for me baby\n'Cause I love the way it feels when we grind\nYeah, our connection's so magnetic on the floor\nNothing can stop us tonight\n\n[Pre-Chorus]\nWhen I'm walkin' with you\nI watch the whole room change\nBaby, that's what you do\nNo my baby don't play\nBlame it on my confidence\nOh, blame it on your measurements\nShut that shit down on sight\nThat's right\n\n[Chorus]\nWe out here drippin' in finesse\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it\nWe out here drippin' in finesse\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it\n\n[Bridge]\nFellas, grab your ladies if your lady fine\nTell her she the one, she the one for life (woo)\nLadies, grab your fellas and let's do this right (do this right)\nIf you're on one like me in mind (ow!)\nYeah, we got it goin' on, got it goin' on\nDon't it feel so good to be us? (ayy)\nYeah, we got it goin' on, got it goin' on (yeah)\nGirl, we got it goin' on\nYeah, we got it goin' on, got it goin' on (hey)\nDon't it feel so good to be us, ayy? (feels so good on you)\nYeah, we got it goin' on, got it goin' on\n\n[Chorus]\nWe out here drippin' in finesse (we drippin' on them)\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it\nWe out here drippin' in finesse with my baby\nIt don't make no sense\nOut here drippin' in finesse\nYou know it, you know it (yeah, you know we got it goin' on)\n\n[Outro]\nYeah, we got it goin' on, got it goin' on\nDon't it feel so good to be us, ayy?\nYeah, we got it goin' on, got it goin' on\nYou know it, you know it\nYeah, we got it goin' on, got it goin' on\nGirl, we got it\nDon't it feel so good to be us, ayy?\nYeah, we got it goin' on, got it goin' on\nYou know it, you know it\n\n"

# %% [markdown]
# Combining the two results and checking the size

# %%
# song_lyrics = song_lyrics2019 + song_lyrics2018
# len(song_lyrics)
# Out:
# 200

# %% [markdown]
# Next, I noticed that I would need to clean up the data a bit. There were a few labels to call out verses/choruses/featured artists, so I wanted to get ride of those.

# %%
# text = song_lyrics[0]
# re.findall('\[.*\]', text)
# Out:
# ["[Verse 1]Mirror, mirror on the wallDon't say it ’cause I know I'm cute (Ooh, baby)Louis down to my drawersLV all on my shoes (Ooh, baby)I be drippin' so much sauceGot a bih lookin’ like RAGÚ (Ooh, baby)Lit up like a crystal ballThat's cool, baby, so is youThat's how I roll[Pre-Chorus]If I'm shinin', everybody gonna shine (Yeah, I'm goals)I was born like this, don't even gotta try (Now you know)I'm like chardonnay, get better over time (So you know)Heard you say I’m not the baddest, bitch, you lie (Haha)[Chorus]"]

# %%
# section_labels = [re.findall('\[[^\]]+\]', song) for song in song_lyrics if song is not None]

# %% [markdown]
# I thought it might be wise to count the instances of these words and take a look at them before I dropped them in case I was getting rid of something that might later become important.

# %%
label_counter = {}

for song in section_labels:
    for label in song:
        if label not in label_counter:
            label_counter[label] = 1
        else:
            label_counter[label] += 1
label_counter
# Out:
# {'[Verse 1]': 82,
#  '[Pre-Chorus]': 60,
#  '[Chorus]': 181,
#  '[unverified]': 1,
#  '[Intro]': 27,
#  '[Verse 2]': 59,
#  '[Bridge]': 30,
#  '[Outro]': 21,
#  '[Verse I]': 2,
#  '[Verse II]': 2,
#  '[Spoken Intro]': 1,
#  '[Pre-Chorus 1]': 3,
#  '[Verse 3]': 13,
#  '[Intro: Timbaland]': 1,
#  '[Verse 1: Nelly Furtado & (Timbaland)]': 1,
#  '[Chorus: Nelly Furtado]': 3,
#  '[Verse 2: Nelly Furtado & (Timbaland)]': 1,
#  '[Interlude: Nelly Furtado & (Timbaland)]': 1,
#  '[Bridge: Nelly Furtado & (Timbaland)]': 1,
#  '[Post-Chorus]': 5,
#  '[Interlude]': 6,
#  '[Chorus: Bailey & Collins]': 2,
#  '[Verse 1: Bailey]': 2,
#  '[Bridge: Collins]': 4,
#  '[Verse 2: Bailey]': 2,
#  '[Instrumental]': 2,
#  '[Bridge: Bailey & Collins]': 2,
#  '[Verse 1: Cardi B]': 2,
#  '[Verse 2: Bruno Mars]': 2,
#  '[Pre-Chorus: Bruno Mars]': 3,
#  '[Chorus: Bruno Mars]': 3,
#  '[Verse 3: Bruno Mars]': 1,
#  '[Bridge: Bruno Mars & Cardi B]': 1,
#  '[Outro: Cardi B & Bruno Mars, Both]': 1,
#  '[Refrain: Britney Spears]': 3,
#  '[Verse 1: Britney Spears]': 1,
#  '[Verse 2: Britney Spears]': 1,
#  '[Bridge: Giorgio Moroder]': 1,
#  '[Post-Chorus 1]': 1,
#  '[Post-Chorus 2]': 1,
#  '[Spoken Outro]': 1,
#  '[Refrain]': 9,
#  '[Spoken]': 3,
#  '[Intro: Spoken]': 1,
#  '[Verse 4]': 2,
#  '[Verse 5]': 2,
#  '[Hook]': 14,
#  '[Ad-Libbing]': 1,
#  '[Instrumental Outro]': 2,
#  '[Verse 1: Chromeo]': 2,
#  '[Verse 2: Amber Mark & Chromeo]': 2,
#  '[Chorus: Chromeo & Amber Mark]': 4,
#  '[Verse 3: Chromeo]': 2,
#  '[Verse 4: Amber Mark & Chromeo]': 2,
#  '[Bridge: Amber Mark]': 2,
#  '[Outro: Amber Mark]': 2,
#  '[Intro: Brigitte Arens]': 1,
#  '[Verse 1: Steve Strange]': 1,
#  '[Chorus: Steve Strange]': 2,
#  '[Spoken Word: Brigitte Arens]': 1,
#  '[Chorus: Ice Cube]': 4,
#  '[Bridge: Ice Cube]': 4,
#  '[Verse 1: Ice Cube]': 1,
#  '[Pre-Chorus: Ice Cube]': 1,
#  '[Verse 2: Ice Cube]': 1,
#  '[Verse 3: Ice Cube]': 1,
#  '[Bridge: Dom Kennedy]': 1,
#  '[Verse 1: Dave 1]': 1,
#  '[Verse 2: Dave 1]': 1,
#  '[Verse]': 1,
#  '[Bridge: Lulu & Take That]': 1,
#  '[Chorus 1]': 3,
#  '[Produced by Sounwave; Additional production by Terrace Martin]': 1,
#  '[Intro: Kendrick Lamar]': 1,
#  '[Chorus 1: Kendrick Lamar]': 1,
#  '[Verse 1: Kendrick Lamar]': 1,
#  '[Breakdown]': 2,
#  '[Instrumental Break]': 1,
#  '[Intro: Pitbull]': 1,
#  '[Verse 1: Pitbull]': 1,
#  '[Pre-Chorus: Pitbull]': 2,
#  '[Chorus: John Ryan]': 2,
#  '[Verse 2: Pitbull]': 1,
#  '[Bridge: Pitbull]': 1,
#  '[Intro: Major Lazer]': 1,
#  '[Verse 1: Nyla]': 1,
#  '[Pre-Hook 1: Nyla]': 1,
#  '[Hook: Nyla]': 3,
#  '[Verse 2: Fuse ODG]': 1,
#  '[Pre-Hook 2: Fuse ODG]': 2,
#  '[Outro: Nyla]': 1,
#  '[Instrumental break]': 1,
#  '[Verse 1: Ne-Yo]': 1,
#  '[Bridge: Ne-Yo]': 1,
#  '[Hook: Ne-Yo]': 1,
#  '[Intro: Unnamed Man & Bruno Mars]': 1,
#  '[Verse 1: Bruno Mars and (Backing Vocalists)]': 1,
#  '[Verse 2: Bruno Mars and (Backing Vocalists)]': 1,
#  '[Spoken Russian throughout]': 1,
#  '[K-Ci & Will Smith:]': 2,
#  '[Verse 1: Will Smith]': 1,
#  '[K-Ci:]': 5,
#  '[Verse 2: Will Smith]': 1,
#  '[Verse 3: Will Smith]': 1,
#  '[Bridge: Will Smith]': 1,
#  '[Outro: Will Smith]': 1,
#  '[Verse 1: Tinie Tempah]': 1,
#  '[Chorus: Zara Larsson]': 1,
#  '[Drop]': 3,
#  '[Bridge 1]': 1,
#  '[Solo]': 1,
#  '[Bridge 2]': 1,
#  '[STAR]': 1,
#  '[Pre-Chorus 2]': 1,
#  '[Produced by L.E.S. and Poke & Tone]': 1,
#  '[Verse 1: Luther Vandross]': 1,
#  '[Verse 2: Luther Vandross]': 1,
#  '[VALENCIA]': 3,
#  '[HEATHER]': 3,
#  '[PAULA]': 5,
#  '[REBECCA]': 5,
#  '[ALL]': 2,
#  '[Chorus - ALL]': 3,
#  '[VALENCIA, HEATHER, AND PAULA]': 1,
#  '[PAULA, HEATHER, AND VALENCIA]': 1,
#  '[REBECCA, spoken]': 1,
#  '[PAULA, spoken]': 2,
#  '[REBECCA, VALENCIA, AND HEATHER]': 1,
#  '[Verse I: Patrice Rushen]': 1,
#  '[Chorus: Patrice Rushen]': 1,
#  '[Verse II: Roy Galloway]': 1,
#  '[Chorus: Roy Galloway]': 1,
#  '[Verse: Kavinsky]': 2,
#  '[Chorus: Lovefoxxx]': 2,
#  '[Chorus: Boy George]': 1,
#  '[Verse 1: Andrew Wyatt]': 1,
#  '[Pre-Chorus: Andrew Wyatt & Boy George]': 1,
#  '[Chorus: Andrew Wyatt & Boy George]': 1,
#  '[Intro: Scat]': 1}

# %% [markdown]
# Looking at the results, I was comfortable getting rid of these words. Additionally, I eliminated the new lines, and then added spaces in their place.
#
#
# Later when I would start generating lyrics, I found that it used profanity quite liberally, so I thought it might be wise to clean up the language a bit to make it less colourful. I used an additional Python library to do this.

# %%
# without_labels = [re.sub('\[[^\]]+\]', '', song) for song in song_lyrics if song is not None]
# without_newline = [re.sub('\n', ' ', song) for song in without_labels]
# respace_words = [re.sub('([a-z])([A-Z])', "\g<1> \g<2>", song) for song in without_newline]
# lyrics_final = [profanity.censor(song) for song in respace_words]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-067ada2c7d50> in <module>
# ----> 1 without_labels = [re.sub('\[[^\]]+\]', '', song) for song in song_lyrics if song is not None]
#       2 without_newline = [re.sub('\n', ' ', song) for song in without_labels]
#       3 respace_words = [re.sub('([a-z])([A-Z])', "\g<1> \g<2>", song) for song in without_newline]
#       4 lyrics_final = [profanity.censor(song) for song in respace_words]
#
# NameError: name 'song_lyrics' is not defined

# %% [markdown]
# Next, I added the lyrics to a dataframe to make them easier for the algorithm to process.

# %%
lyrics = pd.DataFrame(lyrics_final, columns=['lines'])
lyrics.head()
# Out:
#                                                lines
# 0  Mirror, mirror on the wall Don't say it ’cause...
# 1  I've never been closer I tried to understand T...
# 2    Steppin' out the weekends open wide Fill it ...
# 3  I hold you, I touch you In a maze, can't find ...
# 4  Have you heard that there's an ad Listed in th...

# %% [markdown]
# Finally, the data is ready, so I saved it. In the end, I maanged to pull 137 / 200 songs (the remainder of which weren't in the Genius database).

# %%
lyrics = pd.read_csv('../data/data')

# lyrics.shape
# Out:
# (137, 2)

# %% [markdown]
# Next, Ive created the x train and y train set. The x train set goes up to the penultimate word in the line, so the target is the final word.
# The y train set starts from the second word in the line to compensate for this.

# %%
# x_train = [line[:-1] for line in lyrics.lines]
# y_train = [line[1:] for line in lyrics.lines]

# %% [markdown]
# In order for the model to process the data, it needs numbers instead of words, so I used the tokenizer to assign each word an index.

# %%
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(lyrics.lines)
# x_train = tokenizer.texts_to_sequences(x_train)
# y_train = tokenizer.texts_to_sequences(y_train)

# %% [markdown]
# We'll need to switch between the index and words eventually, so the below will assign the
# index and retrieve word from the index later on.

# %%
# word2index = tokenizer.word_index
# index2word = {value: key for key, value in word2index.items()}

# %%
# word2index["<pad>"] = 0
# index2word[0] = "<pad>"

# %% [markdown]
# Finally, I've defined some parameters for the model below using the describe function.

# %%
# lengths = []

# for sequence in x_train:
#     lengths.append(len(sequence))
    
# lengths = pd.Series(lengths)
# lengths.describe()
# Out:
# count    137.000000
# mean     258.664234
# std      162.111040
# min       28.000000
# 25%      137.000000
# 50%      200.000000
# 75%      345.000000
# max      769.000000
# dtype: float64

# %%
# max_len = 769
# vocab_size = len(tokenizer.word_index) + 1
# embedding_dim = 128
# vocab_size
# Out:
# 2679

# %%
# x_train = pad_sequences(x_train, maxlen=max_len, padding='post', truncating='post')
# y_train = pad_sequences(y_train, maxlen=max_len, padding='post', truncating='post')

# %% [markdown]
# Next, the model is built. the Sequential function groups a linear stack of layers into a model. We add the GRU which stands for Gated Recurrant Unit, and ask this only to return the last word in the sequence of lyrics rather than the whole line. Its optimized to increase speed.
#
#
# Then, we feed it the data. The first time I did this I used only half the data (before I decided to use 2018 data too), and 50 epochs. This took around half an hour.
#
# Later on, I retrained with twice the data and 75 epochs - this took 2-3 hours.

# %%
# model = Sequential()
# model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True))
# model.add(GRU(units=1024, return_sequences=True))
# model.add(Dense(vocab_size))

# %%
# model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(from_logits=True))

# %%
# history = model.fit(x_train, y_train, epochs=75, verbose=1)
# Out:
# Epoch 1/75
# 5/5 [==============================] - 111s 22s/step - loss: 2.5463
# Epoch 2/75
# 5/5 [==============================] - 105s 21s/step - loss: 2.3554
# Epoch 3/75
# 5/5 [==============================] - 501s 100s/step - loss: 2.0558
# Epoch 4/75
# 5/5 [==============================] - 107s 21s/step - loss: 1.9944
# Epoch 5/75
# 5/5 [==============================] - 106s 21s/step - loss: 1.9583
# Epoch 6/75
# 5/5 [==============================] - 101s 20s/step - loss: 1.9345
# Epoch 7/75
# 5/5 [==============================] - 95s 19s/step - loss: 1.9088
# Epoch 8/75
# 5/5 [==============================] - 99s 20s/step - loss: 1.8834
# Epoch 9/75
# 5/5 [==============================] - 106s 21s/step - loss: 1.8509
# Epoch 10/75
# 5/5 [==============================] - 129s 26s/step - loss: 1.8210
# Epoch 11/75
# 5/5 [==============================] - 112s 22s/step - loss: 1.7858
# Epoch 12/75
# 5/5 [==============================] - 102s 20s/step - loss: 1.7421
# Epoch 13/75
# 5/5 [==============================] - 103s 21s/step - loss: 1.6678
# Epoch 14/75
# 5/5 [==============================] - 110s 22s/step - loss: 1.6025
# Epoch 15/75
# 5/5 [==============================] - 122s 24s/step - loss: 1.5348
# Epoch 16/75
# 5/5 [==============================] - 110s 22s/step - loss: 1.4684
# Epoch 17/75
# 5/5 [==============================] - 95s 19s/step - loss: 1.3971
# Epoch 18/75
# 5/5 [==============================] - 102s 20s/step - loss: 1.3275
# Epoch 19/75
# 5/5 [==============================] - 98s 20s/step - loss: 1.2566
# Epoch 20/75
# 5/5 [==============================] - 107s 21s/step - loss: 1.1816
# Epoch 21/75
# 5/5 [==============================] - 94s 19s/step - loss: 1.1178
# Epoch 22/75
# 5/5 [==============================] - 104s 21s/step - loss: 1.0503
# Epoch 23/75
# 5/5 [==============================] - 97s 19s/step - loss: 0.9902
# Epoch 24/75
# 5/5 [==============================] - 108s 22s/step - loss: 0.9351
# Epoch 25/75
# 5/5 [==============================] - 92s 18s/step - loss: 0.8787
# Epoch 26/75
# 5/5 [==============================] - 91s 18s/step - loss: 0.8278
# Epoch 27/75
# 5/5 [==============================] - 92s 18s/step - loss: 0.7783
# Epoch 28/75
# 5/5 [==============================] - 105s 21s/step - loss: 0.7335
# Epoch 29/75
# 5/5 [==============================] - 102s 20s/step - loss: 0.6939
# Epoch 30/75
# 5/5 [==============================] - 97s 19s/step - loss: 0.6516
# Epoch 31/75
# 5/5 [==============================] - 92s 18s/step - loss: 0.6136
# Epoch 32/75
# 5/5 [==============================] - 135s 27s/step - loss: 0.5787
# Epoch 33/75
# 5/5 [==============================] - 130s 26s/step - loss: 0.5434
# Epoch 34/75
# 5/5 [==============================] - 144s 29s/step - loss: 0.5140
# Epoch 35/75
# 5/5 [==============================] - 114s 23s/step - loss: 0.4834
# Epoch 36/75
# 5/5 [==============================] - 111s 22s/step - loss: 0.4561
# Epoch 37/75
# 5/5 [==============================] - 113s 23s/step - loss: 0.4305
# Epoch 38/75
# 5/5 [==============================] - 102s 20s/step - loss: 0.4077
# Epoch 39/75
# 5/5 [==============================] - 101s 20s/step - loss: 0.3852
# Epoch 40/75
# 5/5 [==============================] - 100s 20s/step - loss: 0.3644
# Epoch 41/75
# 5/5 [==============================] - 112s 22s/step - loss: 0.3466
# Epoch 42/75
# 5/5 [==============================] - 104s 21s/step - loss: 0.3292
# Epoch 43/75
# 5/5 [==============================] - 93s 19s/step - loss: 0.3126
# Epoch 44/75
# 5/5 [==============================] - 99s 20s/step - loss: 0.2970
# Epoch 45/75
# 5/5 [==============================] - 91s 18s/step - loss: 0.2836
# Epoch 46/75
# 5/5 [==============================] - 105s 21s/step - loss: 0.2706
# Epoch 47/75
# 5/5 [==============================] - 97s 19s/step - loss: 0.2590
# Epoch 48/75
# 5/5 [==============================] - 94s 19s/step - loss: 0.2482
# Epoch 49/75
# 5/5 [==============================] - 104s 21s/step - loss: 0.2378
# Epoch 50/75
# 5/5 [==============================] - 103s 21s/step - loss: 0.2268
# Epoch 51/75
# 5/5 [==============================] - 103s 21s/step - loss: 0.2167
# Epoch 52/75
# 5/5 [==============================] - 91s 18s/step - loss: 0.2085
# Epoch 53/75
# 5/5 [==============================] - 102s 20s/step - loss: 0.2007
# Epoch 54/75
# 5/5 [==============================] - 95s 19s/step - loss: 0.1931
# Epoch 55/75
# 5/5 [==============================] - 109s 22s/step - loss: 0.1836
# Epoch 56/75
# 5/5 [==============================] - 117s 23s/step - loss: 0.1779
# Epoch 57/75
# 5/5 [==============================] - 139s 28s/step - loss: 0.1714
# Epoch 58/75
# 5/5 [==============================] - 134s 27s/step - loss: 0.1636
# Epoch 59/75
# 5/5 [==============================] - 112s 22s/step - loss: 0.1565
# Epoch 60/75
# 5/5 [==============================] - 112s 22s/step - loss: 0.1512
# Epoch 61/75
# 5/5 [==============================] - 138s 28s/step - loss: 0.1453
# Epoch 62/75
# 5/5 [==============================] - 114s 23s/step - loss: 0.1401
# Epoch 63/75
# 5/5 [==============================] - 108s 22s/step - loss: 0.1340
# Epoch 64/75
# 5/5 [==============================] - 101s 20s/step - loss: 0.1279
# Epoch 65/75
# 5/5 [==============================] - 113s 23s/step - loss: 0.1227
# Epoch 66/75
# 5/5 [==============================] - 108s 22s/step - loss: 0.1175
# Epoch 67/75
# 5/5 [==============================] - 108s 22s/step - loss: 0.1135
# Epoch 68/75
# 5/5 [==============================] - 101s 20s/step - loss: 0.1094
# Epoch 69/75
# 5/5 [==============================] - 104s 21s/step - loss: 0.1044
# Epoch 70/75
# 5/5 [==============================] - 99s 20s/step - loss: 0.0991
# Epoch 71/75
# 5/5 [==============================] - 89s 18s/step - loss: 0.0940
# Epoch 72/75
# 5/5 [==============================] - 80s 16s/step - loss: 0.0903
# Epoch 73/75
# 5/5 [==============================] - 82s 16s/step - loss: 0.0874
# Epoch 74/75
# 5/5 [==============================] - 85s 17s/step - loss: 0.0825
# Epoch 75/75
# 5/5 [==============================] - 85s 17s/step - loss: 0.0790

# %% [markdown]
# To avoid having to retrain the model, you can load the model below. h5 is the first one I trained, h6 is too big to upload to GitHub, so you will have to use h5 instead.

# %%
# model.save("model.h6")
# model = load_model("model.h5")
model = load_model("model.h6")

# %% [markdown]
# The function is going to be fed a word, and based on that word, the model will produce a list of indexes (of words) weighted by how likely they are to follow the initial word given the lyrics in the songs we fed it.
#
#
# In order that it doesn't loop back on itself, for example:
#
# 'I like disco music and I like to dance'
#
# If this was fed to the model without tweaking, from the first part of the sentence you can see that 'disco' is most likely to follow 'like' which is why it was chosen. However, when 'I like' appears again, then the model would want to choose 'disco' again, because that is the most likely word to follow 'like' as we've already seen.
#
# In order to avoid this, the next function will find the top x most likely indices (words) to follow, and will choose a random index (word) from that list instead.

# %%
def select_next_word(predictions):
    '''
    input: list of numbers showing weighting or prediction to be next word, indices correspond to 
    words 
    output: random index from top 5 predicted words 
    '''
    return random.choice(sorted(list(zip(predictions, 
                                         range(len(predictions)))), reverse = True)[:7])[1]

# %%
def generate(word):
    inputs = np.zeros((1, 1))
    inputs[0, 0] = word2index[word]
    count = 1
    while count <= 50:
        pred = model.predict(inputs)
        next_word_index = select_next_word(list(pred[0][0]))
        
        inputs[0, 0] = next_word_index
        print(index2word[next_word_index], end=" ")
        count += 1

print(generate('tramps'))
# Out:
# space okay okay loved behind behind yi yi yi fly fly fly slow slow yi lazer one it solider you one felt yes trickin' hear thy she's rough rent water tramps case lazer it snore space okay help yi slow water water space war across water tramps tramps case week None

# %%
print(generate('floor'))
# Out:
# hits ahead ahead nobody shine help shine screaming lazer solider None

# %%
pwd
# Out:
# '/Users/ninahew/lyric_generator/code'

# %%
lyrics.to_csv('../../data')

# %%
# Out:
# 'b'
