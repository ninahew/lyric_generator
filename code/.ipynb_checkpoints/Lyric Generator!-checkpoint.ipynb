# %% [markdown]
# # Lyric Generator!
#
# Further to my studies of NLP, I decided to see whether I could harness AI to write new lyrics based on my previous listening habits.

# %%
import spotipy.util as util
import spotipy
import os.path as path
import requests
from bs4 import BeautifulSoup

username = 'ninahew'
spotify_client_id ='a758a8092e3b45949388c4123f79948f'
spotify_client_secret = 'df4c710d84b64ab7810f0b9b055a07f2'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'
genius_key = 'sQkNdeBg0aT9rz89yElRfHbxE_UIW3kFs9IkXPIH6Ab4cH8DvfikT09FU56MVjZP'
spotify_playlist_id = 'spotify:playlist:37i9dQZF1EtmAVggpyt82c'
spotify_user_id = 'spotify:user:ninahew'

from spotipy.oauth2 import SpotifyClientCredentials

#spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, 
#                                                                              client_secret=client_secret))

# %%
class GetLyrics():
    
    def __init__(self, spotify_client_id, spotify_client_secret, user_id, playlist_id, genius_key):
        self.spotify_client_id = spotify_client_id
        self.spotify_client_secret = spotify_client_secret
        self.user_id = user_id
        self.playlist_id = playlist_id
        self.genius_key = genius_key
        
    def get_playlist_info(self):
        token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
        sp = spotipy.Spotify(token)
        playlist = sp.user_playlist_tracks(self.user_id, self.playlist_id)
        self.playlist = playlist
        return self.playlist
    
    def get_track_names(self):
        track_names = []
        for song in range(len(self.playlist['items'])):
            track_names.append(self.playlist['items'][song]['track']['name'])
        self.track_names = track_names
        return self.track_names
    
    def get_track_artists(self):
        track_artists = []
        for song in range(len(self.playlist['items'])):
            track_artists.append(self.playlist['items'][song]['track']['artists'][0]['name'])
        self.track_artists = track_artists
        return self.track_artists
        
    def request_song_info(self, track_name, track_artist):
        self.track_name = track_name
        self.track_artist = track_artist
        base_url = 'https://api.genius.com'
        headers = {'Authorization': 'Bearer ' + self.genius_key}
        search_url = base_url + '/search'
        data = {'q': track_name + ' ' + track_artist}
        response = requests.get(search_url, data=data, headers=headers)
        self.response = response
        return self.response

    def check_hits(self):
        json = self.response.json()
        remote_song_info = None
        for hit in json['response']['hits']:
            if self.track_artist.lower() in hit['result']['primary_artist']['name'].lower():
                remote_song_info = hit
                break
        self.remote_song_info = remote_song_info
        return self.remote_song_info
    
    def get_url(self):
        song_url = self.remote_song_info['result']['url']
        self.song_url = song_url
        return self.song_url
    
    def scrape_lyrics(self):
        page = requests.get(self.song_url)
        html = BeautifulSoup(page.text, 'html.parser')
        lyrics1 = html.find("div", class_="lyrics")
        lyrics2 = html.find("div", class_="Lyrics__Container-sc-1ynbvzw-2 jgQsqn")
        if lyrics1:
            lyrics = lyrics1.get_text()
        elif lyrics2:
            lyrics = lyrics2.get_text()
        elif lyrics1 == lyrics2 == None:
            lyrics = None
        return lyrics

    def get_lyrics(self):
        playlist = GetLyrics.get_playlist_info(self)
        track_names = GetLyrics.get_track_names(self)
        track_artists = GetLyrics.get_track_artists(self)
        song_lyrics = []
        for i in range(len(self.track_names)):
            print("\n")
            print(f"Working on track {i}.")
            response = GetLyrics.request_song_info(self, self.track_names[i], self.track_artists[i])
            remote_song_info = GetLyrics.check_hits(self)
            if remote_song_info == None:
                lyrics = None
                print(f"Track {i} is not in the Genius database.")
            else:
                url = GetLyrics.get_url(self)
                lyrics = GetLyrics.scrape_lyrics(self)
                if lyrics == None:
                    print(f"Track {i} is not in the Genius database.")
                else:
                    print(f"Retrieved track {i} lyrics!")
            song_lyrics.append(lyrics)
        return song_lyrics

# %%
songs2019 = GetLyrics(spotify_client_id, spotify_client_secret, spotify_user_id, spotify_playlist_id, genius_key)
song_lyrics2019 = songs2019.get_lyrics()
# Out:
# <ipython-input-86-7c333718245f>:11: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
# Working on track 0.
# Retrieved track 0 lyrics!
#
#
# Working on track 1.
# Track 1 is not in the Genius database.
#
#
# Working on track 2.
# Track 2 is not in the Genius database.
#
#
# Working on track 3.
# Retrieved track 3 lyrics!
#
#
# Working on track 4.
# Retrieved track 4 lyrics!
#
#
# Working on track 5.
# Retrieved track 5 lyrics!
#
#
# Working on track 6.
# Track 6 is not in the Genius database.
#
#
# Working on track 7.
# Retrieved track 7 lyrics!
#
#
# Working on track 8.
# Track 8 is not in the Genius database.
#
#
# Working on track 9.
# Retrieved track 9 lyrics!
#
#
# Working on track 10.
# Track 10 is not in the Genius database.
#
#
# Working on track 11.
# Retrieved track 11 lyrics!
#
#
# Working on track 12.
# Track 12 is not in the Genius database.
#
#
# Working on track 13.
# Retrieved track 13 lyrics!
#
#
# Working on track 14.
# Track 14 is not in the Genius database.
#
#
# Working on track 15.
# Retrieved track 15 lyrics!
#
#
# Working on track 16.
# Retrieved track 16 lyrics!
#
#
# Working on track 17.
# Track 17 is not in the Genius database.
#
#
# Working on track 18.
# Track 18 is not in the Genius database.
#
#
# Working on track 19.
# Track 19 is not in the Genius database.
#
#
# Working on track 20.
# Retrieved track 20 lyrics!
#
#
# Working on track 21.
# Track 21 is not in the Genius database.
#
#
# Working on track 22.
# Retrieved track 22 lyrics!
#
#
# Working on track 23.
# Retrieved track 23 lyrics!
#
#
# Working on track 24.
# Retrieved track 24 lyrics!
#
#
# Working on track 25.
# Retrieved track 25 lyrics!
#
#
# Working on track 26.
# Retrieved track 26 lyrics!
#
#
# Working on track 27.
# Retrieved track 27 lyrics!
#
#
# Working on track 28.
# Retrieved track 28 lyrics!
#
#
# Working on track 29.
# Track 29 is not in the Genius database.
#
#
# Working on track 30.
# Retrieved track 30 lyrics!
#
#
# Working on track 31.
# Retrieved track 31 lyrics!
#
#
# Working on track 32.
# Track 32 is not in the Genius database.
#
#
# Working on track 33.
# Track 33 is not in the Genius database.
#
#
# Working on track 34.
# Retrieved track 34 lyrics!
#
#
# Working on track 35.
# Retrieved track 35 lyrics!
#
#
# Working on track 36.
# Retrieved track 36 lyrics!
#
#
# Working on track 37.
# Track 37 is not in the Genius database.
#
#
# Working on track 38.
# Track 38 is not in the Genius database.
#
#
# Working on track 39.
# Track 39 is not in the Genius database.
#
#
# Working on track 40.
# Track 40 is not in the Genius database.
#
#
# Working on track 41.
# Track 41 is not in the Genius database.
#
#
# Working on track 42.
# Track 42 is not in the Genius database.
#
#
# Working on track 43.
# Retrieved track 43 lyrics!
#
#
# Working on track 44.
# Retrieved track 44 lyrics!
#
#
# Working on track 45.
# Retrieved track 45 lyrics!
#
#
# Working on track 46.
# Retrieved track 46 lyrics!
#
#
# Working on track 47.
# Retrieved track 47 lyrics!
#
#
# Working on track 48.
# Retrieved track 48 lyrics!
#
#
# Working on track 49.
# Retrieved track 49 lyrics!
#
#
# Working on track 50.
# Retrieved track 50 lyrics!
#
#
# Working on track 51.
# Track 51 is not in the Genius database.
#
#
# Working on track 52.
# Track 52 is not in the Genius database.
#
#
# Working on track 53.
# Track 53 is not in the Genius database.
#
#
# Working on track 54.
# Retrieved track 54 lyrics!
#
#
# Working on track 55.
# Track 55 is not in the Genius database.
#
#
# Working on track 56.
# Retrieved track 56 lyrics!
#
#
# Working on track 57.
# Track 57 is not in the Genius database.
#
#
# Working on track 58.
# Retrieved track 58 lyrics!
#
#
# Working on track 59.
# Track 59 is not in the Genius database.
#
#
# Working on track 60.
# Track 60 is not in the Genius database.
#
#
# Working on track 61.
# Track 61 is not in the Genius database.
#
#
# Working on track 62.
# Retrieved track 62 lyrics!
#
#
# Working on track 63.
# Retrieved track 63 lyrics!
#
#
# Working on track 64.
# Track 64 is not in the Genius database.
#
#
# Working on track 65.
# Track 65 is not in the Genius database.
#
#
# Working on track 66.
# Retrieved track 66 lyrics!
#
#
# Working on track 67.
# Retrieved track 67 lyrics!
#
#
# Working on track 68.
# Track 68 is not in the Genius database.
#
#
# Working on track 69.
# Retrieved track 69 lyrics!
#
#
# Working on track 70.
# Track 70 is not in the Genius database.
#
#
# Working on track 71.
# Retrieved track 71 lyrics!
#
#
# Working on track 72.
# Retrieved track 72 lyrics!
#
#
# Working on track 73.
# Retrieved track 73 lyrics!
#
#
# Working on track 74.
# Retrieved track 74 lyrics!
#
#
# Working on track 75.
# Track 75 is not in the Genius database.
#
#
# Working on track 76.
# Retrieved track 76 lyrics!
#
#
# Working on track 77.
# Track 77 is not in the Genius database.
#
#
# Working on track 78.
# Retrieved track 78 lyrics!
#
#
# Working on track 79.
# Retrieved track 79 lyrics!
#
#
# Working on track 80.
# Retrieved track 80 lyrics!
#
#
# Working on track 81.
# Retrieved track 81 lyrics!
#
#
# Working on track 82.
# Track 82 is not in the Genius database.
#
#
# Working on track 83.
# Retrieved track 83 lyrics!
#
#
# Working on track 84.
# Retrieved track 84 lyrics!
#
#
# Working on track 85.
# Retrieved track 85 lyrics!
#
#
# Working on track 86.
# Retrieved track 86 lyrics!
#
#
# Working on track 87.
# Retrieved track 87 lyrics!
#
#
# Working on track 88.
# Retrieved track 88 lyrics!
#
#
# Working on track 89.
# Track 89 is not in the Genius database.
#
#
# Working on track 90.
# Retrieved track 90 lyrics!
#
#
# Working on track 91.
# Track 91 is not in the Genius database.
#
#
# Working on track 92.
# Retrieved track 92 lyrics!
#
#
# Working on track 93.
# Retrieved track 93 lyrics!
#
#
# Working on track 94.
# Retrieved track 94 lyrics!
#
#
# Working on track 95.
# Track 95 is not in the Genius database.
#
#
# Working on track 96.
# Retrieved track 96 lyrics!
#
#
# Working on track 97.
# Retrieved track 97 lyrics!
#
#
# Working on track 98.
# Retrieved track 98 lyrics!
#
#
# Working on track 99.
# Retrieved track 99 lyrics!

# %%
spotify_playlist_id = 'spotify:playlist:37i9dQZF1Ejy4HBpGZqQ6f'
songs2018 = GetLyrics(spotify_client_id, spotify_client_secret, spotify_user_id, spotify_playlist_id, genius_key)
song_lyrics2018 = songs2018.get_lyrics()
# Out:
# <ipython-input-86-7c333718245f>:11: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token = SpotifyClientCredentials(client_id=self.spotify_client_id, client_secret=self.spotify_client_secret).get_access_token()
# Working on track 0.
# Retrieved track 0 lyrics!
#
#
# Working on track 1.
# Retrieved track 1 lyrics!
#
#
# Working on track 2.
# Track 2 is not in the Genius database.
#
#
# Working on track 3.
# Retrieved track 3 lyrics!
#
#
# Working on track 4.
# Track 4 is not in the Genius database.
#
#
# Working on track 5.
# Track 5 is not in the Genius database.
#
#
# Working on track 6.
# Retrieved track 6 lyrics!
#
#
# Working on track 7.
# Retrieved track 7 lyrics!
#
#
# Working on track 8.
# Retrieved track 8 lyrics!
#
#
# Working on track 9.
# Retrieved track 9 lyrics!
#
#
# Working on track 10.
# Retrieved track 10 lyrics!
#
#
# Working on track 11.
# Retrieved track 11 lyrics!
#
#
# Working on track 12.
# Retrieved track 12 lyrics!
#
#
# Working on track 13.
# Retrieved track 13 lyrics!
#
#
# Working on track 14.
# Retrieved track 14 lyrics!
#
#
# Working on track 15.
# Track 15 is not in the Genius database.
#
#
# Working on track 16.
# Track 16 is not in the Genius database.
#
#
# Working on track 17.
# Retrieved track 17 lyrics!
#
#
# Working on track 18.
# Retrieved track 18 lyrics!
#
#
# Working on track 19.
# Retrieved track 19 lyrics!
#
#
# Working on track 20.
# Retrieved track 20 lyrics!
#
#
# Working on track 21.
# Track 21 is not in the Genius database.
#
#
# Working on track 22.
# Retrieved track 22 lyrics!
#
#
# Working on track 23.
# Retrieved track 23 lyrics!
#
#
# Working on track 24.
# Retrieved track 24 lyrics!
#
#
# Working on track 25.
# Retrieved track 25 lyrics!
#
#
# Working on track 26.
# Track 26 is not in the Genius database.
#
#
# Working on track 27.
# Retrieved track 27 lyrics!
#
#
# Working on track 28.
# Retrieved track 28 lyrics!
#
#
# Working on track 29.
# Retrieved track 29 lyrics!
#
#
# Working on track 30.
# Retrieved track 30 lyrics!
#
#
# Working on track 31.
# Retrieved track 31 lyrics!
#
#
# Working on track 32.
# Retrieved track 32 lyrics!
#
#
# Working on track 33.
# Retrieved track 33 lyrics!
#
#
# Working on track 34.
# Retrieved track 34 lyrics!
#
#
# Working on track 35.
# Retrieved track 35 lyrics!
#
#
# Working on track 36.
# Retrieved track 36 lyrics!
#
#
# Working on track 37.
# Retrieved track 37 lyrics!
#
#
# Working on track 38.
# Retrieved track 38 lyrics!
#
#
# Working on track 39.
# Retrieved track 39 lyrics!
#
#
# Working on track 40.
# Retrieved track 40 lyrics!
#
#
# Working on track 41.
# Retrieved track 41 lyrics!
#
#
# Working on track 42.
# Retrieved track 42 lyrics!
#
#
# Working on track 43.
# Track 43 is not in the Genius database.
#
#
# Working on track 44.
# Track 44 is not in the Genius database.
#
#
# Working on track 45.
# Track 45 is not in the Genius database.
#
#
# Working on track 46.
# Retrieved track 46 lyrics!
#
#
# Working on track 47.
# Track 47 is not in the Genius database.
#
#
# Working on track 48.
# Retrieved track 48 lyrics!
#
#
# Working on track 49.
# Retrieved track 49 lyrics!
#
#
# Working on track 50.
# Track 50 is not in the Genius database.
#
#
# Working on track 51.
# Retrieved track 51 lyrics!
#
#
# Working on track 52.
# Retrieved track 52 lyrics!
#
#
# Working on track 53.
# Retrieved track 53 lyrics!
#
#
# Working on track 54.
# Track 54 is not in the Genius database.
#
#
# Working on track 55.
# Retrieved track 55 lyrics!
#
#
# Working on track 56.
# Retrieved track 56 lyrics!
#
#
# Working on track 57.
# Retrieved track 57 lyrics!
#
#
# Working on track 58.
# Retrieved track 58 lyrics!
#
#
# Working on track 59.
# Retrieved track 59 lyrics!
#
#
# Working on track 60.
# Retrieved track 60 lyrics!
#
#
# Working on track 61.
# Retrieved track 61 lyrics!
#
#
# Working on track 62.
# Track 62 is not in the Genius database.
#
#
# Working on track 63.
# Retrieved track 63 lyrics!
#
#
# Working on track 64.
# Track 64 is not in the Genius database.
#
#
# Working on track 65.
# Retrieved track 65 lyrics!
#
#
# Working on track 66.
# Retrieved track 66 lyrics!
#
#
# Working on track 67.
# Retrieved track 67 lyrics!
#
#
# Working on track 68.
# Track 68 is not in the Genius database.
#
#
# Working on track 69.
# Retrieved track 69 lyrics!
#
#
# Working on track 70.
# Retrieved track 70 lyrics!
#
#
# Working on track 71.
# Retrieved track 71 lyrics!
#
#
# Working on track 72.
# Track 72 is not in the Genius database.
#
#
# Working on track 73.
# Track 73 is not in the Genius database.
#
#
# Working on track 74.
# Retrieved track 74 lyrics!
#
#
# Working on track 75.
# Retrieved track 75 lyrics!
#
#
# Working on track 76.
# Track 76 is not in the Genius database.
#
#
# Working on track 77.
# Retrieved track 77 lyrics!
#
#
# Working on track 78.
# Retrieved track 78 lyrics!
#
#
# Working on track 79.
# Retrieved track 79 lyrics!
#
#
# Working on track 80.
# Track 80 is not in the Genius database.
#
#
# Working on track 81.
# Retrieved track 81 lyrics!
#
#
# Working on track 82.
# Retrieved track 82 lyrics!
#
#
# Working on track 83.
# Retrieved track 83 lyrics!
#
#
# Working on track 84.
# Retrieved track 84 lyrics!
#
#
# Working on track 85.
# Track 85 is not in the Genius database.
#
#
# Working on track 86.
# Retrieved track 86 lyrics!
#
#
# Working on track 87.
# Retrieved track 87 lyrics!
#
#
# Working on track 88.
# Track 88 is not in the Genius database.
#
#
# Working on track 89.
# Retrieved track 89 lyrics!
#
#
# Working on track 90.
# Track 90 is not in the Genius database.
#
#
# Working on track 91.
# Retrieved track 91 lyrics!
#
#
# Working on track 92.
# Retrieved track 92 lyrics!
#
#
# Working on track 93.
# Retrieved track 93 lyrics!
#
#
# Working on track 94.
# Retrieved track 94 lyrics!
#
#
# Working on track 95.
# Retrieved track 95 lyrics!
#
#
# Working on track 96.
# Retrieved track 96 lyrics!
#
#
# Working on track 97.
# Retrieved track 97 lyrics!
#
#
# Working on track 98.
# Retrieved track 98 lyrics!
#
#
# Working on track 99.
# Track 99 is not in the Genius database.

# %%
song_lyrics2019[0]
# Out:
# "\n\n[Verse 1]\nMirror, mirror on the wall\nDon't say it ’cause I know I'm cute (Ooh, baby)\nLouis down to my drawers\nLV all on my shoes (Ooh, baby)\nI be drippin' so much sauce\nGot a bih lookin’ like RAGÚ (Ooh, baby)\nLit up like a crystal ball\nThat's cool, baby, so is you\nThat's how I roll\n\n[Pre-Chorus]\nIf I'm shinin', everybody gonna shine (Yeah, I'm goals)\nI was born like this, don't even gotta try (Now you know)\nI'm like chardonnay, get better over time (So you know)\nHeard you say I’m not the baddest, bitch, you lie (Haha)\n\n[Chorus]\nIt ain’t my fault that I'm out here gettin’ loose\nGotta blame it on the Goose\nGotta blame it on my juice, baby\nIt ain't my fault that I'm out here makin' news\nI’m the pudding in the proof\nGotta blame it on my juice\nYa-ya-ee, ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice\nYa-ya-ee, ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice (Ooh, baby)\n\n[Verse 2]\nNo, I'm not a snack at all\nLook, baby, I'm the whole damn meal (Ooh, baby)\nDavid, you ain't bein' slick\nDon't dare try to cop a feel (Ooh, baby)\nThe juice ain't worth the squeeze\nIf the juice don't look like this (Like this, like this, like this)\nHold up, nigga, please\nDon't make me have to take your bitch, shit (How I roll)\n\n[Pre-Chorus]\nIf I'm shinin', everybody gonna shine (Yeah, I'm goals)\nI was born like this, don't even gotta try (Now you know)\nI'm like chardonnay (Okay), get better over time (So you know)\nHeard you say I'm not the baddest, bitch, you lie (You lie)\n\n[Chorus]\nIt ain't my fault that I'm out here gettin' loose\nGotta blame it on the Goose\nGotta blame it on my juice, baby\nIt ain't my fault that I'm out here makin' news\nI'm the pudding in the proof\nGotta blame it on my juice\nYa-ya-ee (Ya-ya-ee), ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice\nYa-ya-ee (Ya-ya-ee), ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice (Alright)\nYa-ya-ee\n\n[Bridge]\nSomebody come get this man\nI think he got lost in my DMs, what? My DMs, what?\nYou better come get your man\nI think he wanna be way more than friends, what?\nMore than friends\nWhat you want me to say?\n\n[Chorus]\nIt ain't my fault that I'm out here gettin' loose\nGotta blame it on the Goose\nGotta blame it on my juice, baby\nIt ain't my fault that I'm out here makin' news\nI'm the pudding in the proof (Puddin' in the proof)\nGotta blame it on my juice (Blame it on my juice)\nYa-ya-ee (Yay-ya), ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice\nYa-ya-ee (Ya-ya-ee), ya-ya-ee, ya-ya-ee, ya-ya-ee\nBlame it on my juice, blame it, blame it on my juice\n(Blame it on it, yeah)\n\n"

# %%
song_lyrics2018[0]
# Out:
# "[Verse 1]Ooh, don't we look good together?There's a reason why they watch all night longYeah, know we'll turn heads foreverSo tonight I'm gonna show you off[Pre-Chorus]When I'm walkin' with youI watch the whole room changeBaby, that's what you doNo my baby don't playBlame it on my confidenceOh, blame it on your measurementsShut that shit down on sightThat's right[Chorus]We out here drippin' in finesseIt don't make no senseOut here drippin' in finesseYou know it, you know itWe out here drippin' in finesseIt don't make no senseOut here drippin' in finesseYou know it, you know it"

# %%
song_lyrics = song_lyrics2019 + song_lyrics2018
len(song_lyrics)
# Out:
# 200

# %%
import re

# %%
text = song_lyrics[0]
re.findall('\[.*\]', text)
# Out:
# ['[Verse 1]',
#  '[Pre-Chorus]',
#  '[Chorus]',
#  '[Verse 2]',
#  '[Pre-Chorus]',
#  '[Chorus]',
#  '[Bridge]',
#  '[Chorus]']

# %%
section_labels = [re.findall('\[[^\]]+\]', song) for song in song_lyrics if song is not None]

# %%
label_counter = {}

for song in section_labels:
    for label in song:
        if label not in label_counter:
            label_counter[label] = 1
        else:
            label_counter[label] += 1
label_counter
# Out:
# {'[Verse 1]': 82,
#  '[Pre-Chorus]': 55,
#  '[Chorus]': 169,
#  '[Verse 2]': 57,
#  '[Bridge]': 24,
#  '[Instrumental break]': 2,
#  '[Verse 3]': 12,
#  '[unverified]': 1,
#  '[Intro]': 27,
#  '[Verse I]': 2,
#  '[Verse II]': 2,
#  '[Verse III]': 2,
#  '[Spoken Intro]': 1,
#  '[Pre-Chorus 1]': 3,
#  '[Intro: Timbaland]': 1,
#  '[Verse 1: Nelly Furtado & (Timbaland)]': 1,
#  '[Chorus: Nelly Furtado]': 1,
#  '[Post-Chorus]': 5,
#  '[Chorus: Bailey & Collins]': 2,
#  '[Verse 1: Bailey]': 2,
#  '[Bridge: Collins]': 3,
#  '[Verse 1: Cardi B]': 2,
#  '[Verse 2: Bruno Mars]': 2,
#  '[Pre-Chorus: Bruno Mars]': 3,
#  '[Chorus: Bruno Mars]': 3,
#  '[Verse 3: Bruno Mars]': 1,
#  '[Bridge: Bruno Mars & Cardi B]': 1,
#  '[Outro: Cardi B & Bruno Mars, Both]': 1,
#  '[Instrumental]': 2,
#  '[Refrain: Britney Spears]': 3,
#  '[Verse 1: Britney Spears]': 1,
#  '[Verse 2: Britney Spears]': 1,
#  '[Bridge: Giorgio Moroder]': 1,
#  '[Post-Chorus 1]': 2,
#  '[Post-Chorus 2]': 2,
#  '[Spoken Outro]': 1,
#  '[Refrain]': 7,
#  '[Spoken]': 3,
#  '[Intro: Spoken]': 1,
#  '[Interlude]': 5,
#  '[Outro]': 19,
#  '[Harmonica Solo]': 2,
#  '[Verse 4]': 3,
#  '[Verse 5]': 3,
#  '[Pre-Chorus 2]': 3,
#  '[Chorus 2]': 4,
#  '[Hook]': 12,
#  '[Verse 1: Chromeo]': 2,
#  '[Verse 2: Amber Mark & Chromeo]': 2,
#  '[Chorus: Chromeo & Amber Mark]': 3,
#  '[Verse 1 (spoken)]': 1,
#  '[Intro: Brigitte Arens]': 1,
#  '[Verse 1: Steve Strange]': 1,
#  '[Chorus: Steve Strange]': 3,
#  '[Spoken Word: Brigitte Arens]': 2,
#  '[Verse 2: Steve Strange]': 1,
#  '[Chorus: Steve Strange & Brigitte Arens]': 1,
#  '[Chorus: Ice Cube]': 1,
#  '[Bridge: Ice Cube]': 2,
#  '[Verse 1: Ice Cube]': 1,
#  '[Verse 1: Dave 1]': 1,
#  '[Verse 2: Dave 1]': 1,
#  '[Verse]': 1,
#  '[Bridge: Lulu & Take That]': 1,
#  '[Chorus 1]': 3,
#  '[Chorus 3]': 1,
#  '[Produced by Sounwave; Additional production by Terrace Martin]': 1,
#  '[Intro: Kendrick Lamar]': 1,
#  '[Chorus 1: Kendrick Lamar]': 1,
#  '[Verse 1: Kendrick Lamar]': 1,
#  '[Breakdown]': 2,
#  '[Instrumental Break]': 1,
#  '[Verse 3: Chromeo]': 1,
#  '[Verse 4: Amber Mark & Chromeo]': 1,
#  '[Bridge: Amber Mark]': 1,
#  '[Outro: Amber Mark]': 1,
#  '[Intro: Pitbull]': 1,
#  '[Verse 1: Pitbull]': 1,
#  '[Pre-Chorus: Pitbull]': 2,
#  '[Chorus: John Ryan]': 2,
#  '[Verse 2: Pitbull]': 1,
#  '[Bridge: Pitbull]': 1,
#  '[Intro: Major Lazer]': 1,
#  '[Verse 1: Nyla]': 1,
#  '[Pre-Hook 1: Nyla]': 1,
#  '[Hook: Nyla]': 1,
#  '[Verse 1: Ne-Yo]': 1,
#  '[Bridge: Ne-Yo]': 2,
#  '[Hook: Ne-Yo]': 3,
#  '[Verse 2: Ne-Yo]': 1,
#  '[Verse 3: Ne-Yo]': 1,
#  '[Intro: Unnamed Man & Bruno Mars]': 1,
#  '[Verse 1: Bruno Mars and (Backing Vocalists)]': 1,
#  '[Spoken Russian throughout]': 1,
#  '[Instrumental Outro]': 1,
#  '[K-Ci & Will Smith:]': 1,
#  '[Verse 1: Will Smith]': 1,
#  '[Verse 1: Tinie Tempah]': 1,
#  '[Chorus: Zara Larsson]': 1,
#  '[Drop]': 3,
#  '[Chorus - Var. 1]': 1,
#  '[Bridge 1]': 1,
#  '[Solo]': 1,
#  '[Bridge 2]': 1,
#  '[STAR]': 1,
#  '[Produced by L.E.S. and Poke & Tone]': 1,
#  '[Verse 1: Luther Vandross]': 1,
#  '[Verse 2: Luther Vandross]': 1,
#  '[Bridge: Luther + (background)]': 2,
#  '[Verse 3: Luther Vandross]': 1,
#  '[Verse 4: Luther Vandross]': 1,
#  '[Verse 6]': 1,
#  '[Verse 7]': 1,
#  '[Verse 8]': 1,
#  '[VALENCIA]': 1,
#  '[HEATHER]': 1,
#  '[PAULA]': 2,
#  '[REBECCA]': 2,
#  '[ALL]': 1,
#  '[Chorus - ALL]': 1,
#  '[Verse I: Patrice Rushen]': 1,
#  '[Chorus: Patrice Rushen]': 1,
#  '[Verse II: Roy Galloway]': 1,
#  '[Chorus: Roy Galloway]': 1,
#  '[Verse III: Patrice Rushen]': 1,
#  '[Chorus: Patrice Rushen & Roy Galloway]': 2,
#  '[Verse IV: Patrice Rushen & Roy Galloway]': 1,
#  '[Verse: Kavinsky]': 2,
#  '[Chorus: Lovefoxxx]': 2,
#  '[Chorus: Boy George]': 1,
#  '[Verse 1: Andrew Wyatt]': 1,
#  '[Pre-Chorus: Andrew Wyatt & Boy George]': 1,
#  '[Chorus: Andrew Wyatt & Boy George]': 1,
#  '[Intro: Scat]': 1,
#  '[Verse 2: Bailey]': 1,
#  '[Bridge: Bailey & Collins]': 1}

# %%
from better_profanity import profanity
without_labels = [re.sub('\[[^\]]+\]', '', song) for song in song_lyrics if song is not None]
without_newline = [re.sub('\n', ' ', song) for song in without_labels]
respace_words = [re.sub('([a-z])([A-Z])', "\g<1> \g<2>", song) for song in without_newline]
lyrics_final = [profanity.censor(song) for song in respace_words]

# %%
import pandas as pd
lyrics = pd.DataFrame(lyrics_final, columns=['lines'])
lyrics.head()
# Out:
#                                                lines
# 0     Mirror, mirror on the wall Don't say it ’ca...
# 1    I've never been closer I tried to understand...
# 2  Steppin' out the weekends open wide Fill it up...
# 3     I hold you, I touch you In a maze, can't fi...
# 4    Have you heard that there's an ad Listed in ...

# %%
lyrics.shape
# Out:
# (138, 1)

# %%
x_train = [line[:-1] for line in lyrics.lines]
y_train = [line[1:] for line in lyrics.lines]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lyrics.lines)
x_train = tokenizer.texts_to_sequences(x_train)
y_train = tokenizer.texts_to_sequences(y_train)

# %%
word2index = tokenizer.word_index
index2word = {value: key for key, value in word2index.items()}

# %%
word2index["<pad>"] = 0
index2word[0] = "<pad>"

# %%
lengths = []

for sequence in x_train:
    lengths.append(len(sequence))
    
lengths = pd.Series(lengths)
lengths.describe()
# Out:
# count    138.000000
# mean     234.804348
# std      139.655251
# min        0.000000
# 25%      139.000000
# 50%      185.500000
# 75%      303.000000
# max      670.000000
# dtype: float64

# %%
max_len = 769
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128
vocab_size
# Out:
# 2589

# %%
x_train = pad_sequences(x_train, maxlen=max_len, padding='post', truncating='post')
y_train = pad_sequences(y_train, maxlen=max_len, padding='post', truncating='post')

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GRU, Dense, Input, Embedding, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
# model = Sequential()
# model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True))
# model.add(GRU(units=1024, return_sequences=True))
# model.add(Dense(vocab_size))

# %%
# model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(from_logits=True))

# %%
# history = model.fit(x_train, y_train, epochs=50, verbose=1)

# %%
# model.save("model.h5")
model = load_model("model.h5")

# %%
# Out:
# [(3, 4), (4, 3)]

# %%
def select_next_word(predictions):
    '''
    input: list of numbers showing weighting or prediction to be next word, indices correspond to 
    words 
    output: random index from top 5 predicted words 
    '''
    return random.choice(sorted(list(zip(predictions, 
                                         range(len(predictions)))), reverse = True)[:3])[1]

# %%
import numpy as np
import random

def generate(word):
    inputs = np.zeros((1, 1))
    inputs[0, 0] = word2index[word]
    count = 1
    while count <= 100:
        pred = model.predict(inputs)
        next_word_index = select_next_word(list(pred[0][0]))
        next_word_index2 = pred.argpartition(kth=1)[0]
    
        inputs[0, 0] = next_word_index
        print(index2word[next_word_index], end=" ")
        count += 1

print(generate('know'))
# Out:
# see hey loves rock to know see rock limit love the us to hey through zone mother rock limit o mother rock an aussi mother to rock an getting of these i'm know i that's know i that's you got take ain't we had us to hey through who there's know i that's know see hey through zone mother to rock limit o moments the us to hey it know i that's rock limit the us rock an getting we had us know see know i that's you hey it in getting we had of mother rock an aussi mother None

# %%
print(generate('floor'))
# Out:
# know i me for moments o mother to rock to know at rock to know see know at rock an aussi us know see rock limit the us rock to rock an getting of these to hey it my rings we had getting we had getting hit love fade hey it my i give it know i me the mother to know at know see hey loves rock an getting of these i'm hey it my rings we had getting we you hey it my i give else come rock limit o mother rock limit the us rock an cars None

# %%
import numpy as np
import random

def generate2(word):
    inputs = np.zeros((1, 1))
    inputs[0, 0] = word2index[word]
    count = 1
    while count <= 100:
        pred = model.predict(inputs)
        next_word_index = pred.argpartition(kth =1, axis=None)[-5:][random.randint(0,4)]
        print(next_word_index)
#         if next_word_index >= vocab_size:
#             next_word_index = vocab_size - 1
            
#         inputs[0, 0] = next_word_index
#         print(index2word[next_word_index], end=" ")
        count += 1

    
print(generate2('floor'))
# Out:
# 2182
# 2182
# 2178
# 2178
# 2180
# 2179
# 2181
# 2181
# 2178
# 2182
# 2179
# 2178
# 2179
# 2180
# 2180
# 2181
# 2182
# 2181
# 2182
# 2181
# 2180
# 2180
# 2181
# 2181
# 2181
# 2181
# 2182
# 2179
# 2179
# 2178
# 2182
# 2179
# 2179
# 2180
# 2178
# 2178
# 2179
# 2179
# 2179
# 2181
# 2181
# 2182
# 2179
# 2181
# 2180
# 2178
# 2179
# 2178
# 2179
# 2178
# 2180
# 2182
# 2179
# 2179
# 2181
# 2182
# 2181
# 2179
# 2182
# 2181
# 2178
# 2180
# 2181
# 2181
# 2179
# 2178
# 2181
# 2178
# 2180
# 2179
# 2180
# 2181
# 2180
# 2180
# 2178
# 2181
# 2181
# 2182
# 2182
# 2181
# 2178
# 2180
# 2182
# 2180
# 2180
# 2181
# 2179
# 2181
# 2178
# 2181
# 2179
# 2178
# 2180
# 2179
# 2181
# 2182
# 2181
# 2182
# 2182
# 2178
# None

# %%
# Out:
# 'b'
